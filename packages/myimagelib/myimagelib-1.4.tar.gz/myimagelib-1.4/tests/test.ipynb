# %% [markdown]
# # Test
#
# This notebook tests the functions and classes in myimagelib.

# %%
import sys
import os
sys.path.append(os.path.abspath("../src/myimagelib"))
import OFT_funcs as oft
from skimage import io
import matplotlib.pyplot as plt

# %%
img = io.imread(r"G:\My Drive\Research projects\AN\Data\kymo\07_A.tif")[0]
windowShape = [32, 32]
x, y, u_ori, v_ori = oft.imgOrientation(img, windowShape)
# Out:
# c:\Users\zl948\Documents\GitHub\mylib\src\myimagelib\OFT_funcs.py:40: RuntimeWarning: divide by zero encountered in log
#   fft = np.log(fft)
# c:\Users\zl948\Documents\GitHub\mylib\src\myimagelib\OFT_funcs.py:46: RuntimeWarning: invalid value encountered in subtract
#   fft = fft - np.amin(fft)

# %%
plt.imshow(img, cmap='gray')
plt.quiver(x, y, u_ori, v_ori, color='r', scale=.1)

# %%
v_ori[0][0]
# Out:
# 0.0

# %%
1.57/(3**.5)
# Out:
# 0.9064399226277126
