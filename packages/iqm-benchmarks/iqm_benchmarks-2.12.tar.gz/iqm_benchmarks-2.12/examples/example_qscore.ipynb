# %%
# %load_ext autoreload
# %autoreload 2

from iqm.benchmarks.optimization.qscore import *
import random

# %% [markdown]
# # Choose (or define) a backend

# %%
#backend = "fakeadonis"
#backend = "fakeapollo"
#backend = "garnet"
#backend = "deneb"
backend = "pyrite"

# %% [markdown]
# #### Set IQM Token if using Resonance.

# %%
import os
os.environ["IQM_TOKEN"] = "XXXXXXXXXXXXXX"

# %% [markdown]
# # Qscore Configuration

# %%
EXAMPLE_QSCORE = QScoreConfiguration(
    num_instances = 100,
    num_qaoa_layers= 1,
    shots = 20_000,
    calset_id=None, # calibration set ID, default is None
    min_num_nodes =  2,
    max_num_nodes = 5,
    use_virtual_node = True,
    use_classically_optimized_angles = True,
    choose_qubits_routine = "custom",
    custom_qubits_array=[
                    [2, 0],
                    [2, 0, 1],
                    [2, 0, 1, 3],
                    [2, 0, 1, 3, 4]],
    seed = random.randint(1, 999999),
    )

# %% [markdown]
# # Run the experiment

# %%
benchmark_qscore = QScoreBenchmark(backend, EXAMPLE_QSCORE)
run0_qscore = benchmark_qscore.run()
# Out:
# /opt/anaconda3/envs/iqm-benchmarks/lib/python3.11/site-packages/iqm/iqm_client/iqm_client.py:132: UserWarning: Your IQM Client version 20.9 was built for a different version of IQM Server. You might encounter issues. For the best experience, consider using a version of IQM Client that satisfies 18.0 <= iqm-client < 19.0.
#   warnings.warn(version_incompatibility_msg)
# /opt/anaconda3/envs/iqm-benchmarks/lib/python3.11/site-packages/iqm/qiskit_iqm/iqm_provider.py:170: UserWarning: Unknown backend option(s): {'calibration_set_id'}
#   warnings.warn(f'Unknown backend option(s): {unknown_options}')
# /opt/anaconda3/envs/iqm-benchmarks/lib/python3.11/site-packages/iqm/qiskit_iqm/iqm_provider.py:170: UserWarning: Unknown backend option(s): {'calibration_set_id'}
#   warnings.warn(f'Unknown backend option(s): {unknown_options}')
# /opt/anaconda3/envs/iqm-benchmarks/lib/python3.11/site-packages/iqm/qiskit_iqm/iqm_provider.py:170: UserWarning: Unknown backend option(s): {'calibration_set_id'}
#   warnings.warn(f'Unknown backend option(s): {unknown_options}')

# %% [markdown]
# # Perform Analysis

# %%
result0_qscore = benchmark_qscore.analyze()
# Out:
# 2025-01-08 21:48:29,124 - iqm.benchmarks.logging_config - INFO - Q-Score = 2 passed with approximation ratio (Beta) 0.4568; Avg MaxCut size: 0.4800
# 2025-01-08 21:48:29,742 - iqm.benchmarks.logging_config - INFO - Q-Score = 3 passed with approximation ratio (Beta) 0.7552; Avg MaxCut size: 1.4485
# 2025-01-08 21:48:30,565 - iqm.benchmarks.logging_config - INFO - Q-Score = 4 passed with approximation ratio (Beta) 0.5959; Avg MaxCut size: 2.3486
# 2025-01-08 21:48:31,729 - iqm.benchmarks.logging_config - INFO - Q-Score = 5 passed with approximation ratio (Beta) 0.5046; Avg MaxCut size: 3.5042

# %%
result0_qscore.observations
# Out:
# [BenchmarkObservation(name='approximation_ratio', value=0.45683865076658964, identifier=BenchmarkObservationIdentifier(qubit_indices=2), uncertainty=0.09973318703354996),
#  BenchmarkObservation(name='is_succesful', value='True', identifier=BenchmarkObservationIdentifier(qubit_indices=2), uncertainty=None),
#  BenchmarkObservation(name='Qscore_result', value=2, identifier=BenchmarkObservationIdentifier(qubit_indices=2), uncertainty=None),
#  BenchmarkObservation(name='approximation_ratio', value=0.7551882074436624, identifier=BenchmarkObservationIdentifier(qubit_indices=3), uncertainty=0.07344074766814437),
#  BenchmarkObservation(name='is_succesful', value='True', identifier=BenchmarkObservationIdentifier(qubit_indices=3), uncertainty=None),
#  BenchmarkObservation(name='Qscore_result', value=3, identifier=BenchmarkObservationIdentifier(qubit_indices=3), uncertainty=None),
#  BenchmarkObservation(name='approximation_ratio', value=0.595932584269663, identifier=BenchmarkObservationIdentifier(qubit_indices=4), uncertainty=0.05083819942824168),
#  BenchmarkObservation(name='is_succesful', value='True', identifier=BenchmarkObservationIdentifier(qubit_indices=4), uncertainty=None),
#  BenchmarkObservation(name='Qscore_result', value=4, identifier=BenchmarkObservationIdentifier(qubit_indices=4), uncertainty=None),
#  BenchmarkObservation(name='approximation_ratio', value=0.504587331148708, identifier=BenchmarkObservationIdentifier(qubit_indices=5), uncertainty=0.036299476731335906),
#  BenchmarkObservation(name='is_succesful', value='True', identifier=BenchmarkObservationIdentifier(qubit_indices=5), uncertainty=None),
#  BenchmarkObservation(name='Qscore_result', value=5, identifier=BenchmarkObservationIdentifier(qubit_indices=5), uncertainty=None)]

# %%
result0_qscore.plot_all()
